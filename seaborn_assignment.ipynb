# %%
#Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

'''
Seaborn is a popular Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating informative and visually appealing
statistical graphics. Here are five commonly used plots in Seaborn along with their uses:

1. Scatter Plot:
   - Uses: Scatter plots are used to display the relationship between two continuous variables. They can help identify patterns, clusters, or outliers in the data.

2. Line Plot:
   - Uses: Line plots are ideal for visualizing trends and patterns over time or any other ordered variable. They are commonly used to show the progression of data 
     points and identify trends or changes in a dataset.

3. Histogram:
   - Uses: Histograms are used to represent the distribution of a single continuous variable. They divide the variable into bins and display the frequency or count of
     data points falling into each bin, providing insights into the underlying data distribution.

4. Bar Plot:
   - Uses: Bar plots are effective for comparing categorical variables and their associated values. They display the values of different categories as rectangular bars,
     allowing easy comparison between categories.

5. Heatmap:
   - Uses: Heatmaps are useful for visualizing the relationship between two categorical variables. They use color encoding to represent the magnitude of the relationship
     or the value of a third variable across different categories.

These are just a few examples of plots that can be created using Seaborn. The library provides a wide range of other plot types, such as box plots, violin plots, swarm
plots, and more, each with its own specific uses.
'''
pass

# %%
#Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.

import seaborn as sns

# Load the "fmri" dataset
fmri_data = sns.load_dataset("fmri")

# Plot the line plot using Seaborn
sns.lineplot(x="timepoint", y="signal", hue="event", style="region", data=fmri_data)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
#Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the "titanic" dataset
titanic_data = sns.load_dataset("titanic")

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Box plot for 'age'
sns.boxplot(x='pclass', y='age', data=titanic_data, ax=axes[0])
axes[0].set_title("Box Plot: Age")

# Box plot for 'fare'
sns.boxplot(x='pclass', y='fare', data=titanic_data, ax=axes[1])
axes[1].set_title("Box Plot: Fare")

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %%
#Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the "diamonds" dataset
diamonds_data = sns.load_dataset("diamonds")

# Plot histogram with hue
sns.histplot(data=diamonds_data, x="price", hue="cut")

# Set plot title and labels
plt.title("Histogram of Diamond Prices")
plt.xlabel("Price")
plt.ylabel("Count")

# Display the plot
plt.show()

# %%
#Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

import seaborn as sns

# Load the "iris" dataset
iris_data = sns.load_dataset("iris")

# Plot pair plot with hue
sns.pairplot(data=iris_data, hue="species")

# Display the plot
plt.show()

# %%
#Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the "flights" dataset
flights_data = sns.load_dataset("flights")

# Pivot the dataset to create a matrix form
flights_matrix = flights_data.pivot("month", "year", "passengers")

# Plot the heatmap
sns.heatmap(flights_matrix, cmap="YlGnBu")

# Set plot title and labels
plt.title("Flights Heatmap")
plt.xlabel("Year")
plt.ylabel("Month")

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_70/1805778907.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_matrix = flights_data.pivot("month", "year", "passengers")
